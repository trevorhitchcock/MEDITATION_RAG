# %%
import os
import pandas as pd
import re

# %%
PROJECT_ROOT = "/content/MEDITATION_RAG"
FINALIZED_DIR = os.path.join(PROJECT_ROOT, "data", "finalized")

files = []
texts = []

for filename in os.listdir(FINALIZED_DIR):
    if filename.lower().endswith(".txt"):
        path = os.path.join(FINALIZED_DIR, filename)
        with open(path, "r", encoding="utf-8") as f:
            text = f.read()

        files.append(filename)
        texts.append(text)

df = pd.DataFrame({
    "source_file": files,
    "text": texts
})

df
# Out:
#                                           source_file  \
# 0   week_six_appreciation_meditation.docx_cleaned.txt
# 1         week_three_heal_13_minutes.docx_cleaned.txt
# 2   guided_meditation_connecting_with_values.docx_...
# 3                 week_six_gratitude.docx_cleaned.txt
# 4   introduction_to_no_agenda_practice.docx_cleane...
# 5   guided_meditation_thoughts_and_emotions.docx_c...
# 6   week_one_grounding_meditation_5_minutes.docx_c...
# 7   guided_meditation_self-compassion.docx_cleaned...
# 8    week_four_thoughts_and_emotions.docx_cleaned.txt
# 9   week_four_working_with_thoughts.docx_1_cleaned...
# 10  week_two_breath_as_anchor_12_minutes.docx_clea...
# 11  week_one_awareness_of_breath_and_body_8_minute...
# 12  week_one_mindful_presence_13_minutes.docx_1_cl...
# 13  week_three_working_with_your_inner_critic_13_m...
# 14  week_five_just_like_me_male_voice.docx_cleaned...
# 15  guided_meditation_connecting_to_community.docx...
# 16  guided_meditation_befriending_yourself.docx_cl...
# 17         just_like_me_female_voice.docx_cleaned.txt
# 18  week_two_stop_meditation_9_minutes.docx_cleane...
# 19       guided_meditation_no_agenda.docx_cleaned.txt
# 20                                 cureus_cleaned.txt
#
#                                                  text
# 0   Week Six: Appreciation Allowing yourself to fi...
# 1   Week Three: Heal With this practice, we learn ...
# 2   Guided Meditation: Connecting with Values For ...
# 3   Week Six: Gratitude This is a breath and grati...
# 4   Introduction to no agenda practice The no agen...
# 5   Guided Meditation: Thoughts and Emotions This ...
# 6   Week One: Grounding Meditation So find a relax...
# 7   Guided meditation: Self Compassion Allow yours...
# 8   Week Four: Thoughts and Emotions This is a gui...
# 9   Week Four: Working with Thoughts 00:01 So allo...
# 10  Week Two: Breath as Anchor The breath as an an...
# 11  Week One: Awareness of Breath and Body 00:00 W...
# 12  Week One: Mindful Presence Start by acknowledg...
# 13  Week Three: Working with Your Inner Critic Thi...
# 14  Week Five: Just Like Me So for this practice, ...
# 15  Guided Meditation: Connecting to Community For...
# 16  Guided Meditation: Befriending Yourself Allow ...
# 17  Just Like Me Female Voice When practicing this...
# 18  Week Two: STOP Meditation So you can decide fo...
# 19  Guided Meditation: No Agenda So, notice the po...
# 20  This article discusses the power of meditation...

# %%
def chunk_text(text, chunk_size=150):
    """
    Splits text into word-based chunks. Each chunk has approx chunk_size words.
    Returns a list of chunk strings.
    """
    words = text.split()
    chunks = []

    for i in range(0, len(words), chunk_size):
        chunk = " ".join(words[i:i+chunk_size])
        chunks.append(chunk.strip())

    return chunks

# %%
chunk_records = []

for idx, row in df.iterrows():
    source = row["source_file"]
    full_text = row["text"]

    chunks = chunk_text(full_text, chunk_size=150)

    for i, chunk in enumerate(chunks):
        chunk_records.append({
            "chunk_id": f"{source}_chunk_{i}",
            "source_file": source,
            "chunk_index": i,
            "text": chunk,
            "word_count": len(chunk.split())
        })

# %%
chunks_df = pd.DataFrame(chunk_records)
chunks_df
# Out:
#                                               chunk_id  \
# 0    week_six_appreciation_meditation.docx_cleaned....
# 1    week_six_appreciation_meditation.docx_cleaned....
# 2    week_six_appreciation_meditation.docx_cleaned....
# 3    week_six_appreciation_meditation.docx_cleaned....
# 4    week_three_heal_13_minutes.docx_cleaned.txt_ch...
# ..                                                 ...
# 131                        cureus_cleaned.txt_chunk_15
# 132                        cureus_cleaned.txt_chunk_16
# 133                        cureus_cleaned.txt_chunk_17
# 134                        cureus_cleaned.txt_chunk_18
# 135                        cureus_cleaned.txt_chunk_19
#
#                                            source_file  chunk_index  \
# 0    week_six_appreciation_meditation.docx_cleaned.txt            0
# 1    week_six_appreciation_meditation.docx_cleaned.txt            1
# 2    week_six_appreciation_meditation.docx_cleaned.txt            2
# 3    week_six_appreciation_meditation.docx_cleaned.txt            3
# 4          week_three_heal_13_minutes.docx_cleaned.txt            0
# ..                                                 ...          ...
# 131                                 cureus_cleaned.txt           15
# 132                                 cureus_cleaned.txt           16
# 133                                 cureus_cleaned.txt           17
# 134                                 cureus_cleaned.txt           18
# 135                                 cureus_cleaned.txt           19
#
#                                                   text  word_count
# 0    Week Six: Appreciation Allowing yourself to fi...         150
# 1    you being alive. It's nourishment to the body....         150
# 2    offering another genuine heartfelt thank you. ...         150
# 3    good fortune or good health, try offering, aga...          75
# 4    Week Three: Heal With this practice, we learn ...         150
# ..                                                 ...         ...
# 131  . In today's world, a very under-spoken proble...         150
# 132  only groups . As seen by the results, both med...         150
# 133  the above, we can say that meditation has been...         150
# 134  effect it has on the disease; moreover, the ex...         150
# 135  recommended. For reflective practice to have c...          61
#
# [136 rows x 5 columns]

# %%
chunks_df['word_count'].describe()
# Out:
# count    136.000000
# mean     137.433824
# std       33.687607
# min        8.000000
# 25%      150.000000
# 50%      150.000000
# 75%      150.000000
# max      150.000000
# Name: word_count, dtype: float64
